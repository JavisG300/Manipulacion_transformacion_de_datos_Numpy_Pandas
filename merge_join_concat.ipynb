# %% [markdown]
# Creando data frame

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({'A':['A0','A1','A2','A3'],
'B':['B0','B1','B2','B3'],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3']
})

df2 = pd.DataFrame({'A':['A4','A5','A6','A7'],
'B':['B4','B5','B6','B7'],
'C':['C4','C5','C6','C7'],
'D':['D4','D5','D6','D7']
})

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %% [markdown]
# ## Concat

# %%
pd.concat([df1,df2]) #Para concatenar debe de ir entre corchetes
#Por default es por filas
#Los índices heredan el índice anterior
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 3  A7  B7  C7  D7

# %%
#Para hacer que los índices sigan siendo únicos
pd.concat([df1,df2],ignore_index=True)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
#Para hacerlo por columnas
pd.concat([df1,df2],axis=1)
# Out:
#     A   B   C   D   A   B   C   D
# 0  A0  B0  C0  D0  A4  B4  C4  D4
# 1  A1  B1  C1  D1  A5  B5  C5  D5
# 2  A2  B2  C2  D2  A6  B6  C6  D6
# 3  A3  B3  C3  D3  A7  B7  C7  D7

# %% [markdown]
# ## Merge

# %%
izq = pd.DataFrame({'Key':['k0','k1','k2','k3'],
'A':['A0','A1','A2','A3'],
'B':['B0','B1','B2','B3']
})

der = pd.DataFrame({'Key':['k0','k1','k2','k3'],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3']
})

# %%
izq.merge(der) #Izquierda y derecha nos ayudan a identificar el lado del merge que ocupan
# Out:
#   Key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %% [markdown]
# El merge se hizo por columnas en común

# %% [markdown]
# Podemos hacer **merge** para columnas específicas

# %%
izq.merge(der, on='Key')
# Out:
#   Key   A   B   C   D
# 0  k0  A0  B0  C0  D0
# 1  k1  A1  B1  C1  D1
# 2  k2  A2  B2  C2  D2
# 3  k3  A3  B3  C3  D3

# %%
izq = pd.DataFrame({'Key':['k0','k1','k2','k3'],
'A':['A0','A1','A2','A3'],
'B':['B0','B1','B2','B3']
})

der = pd.DataFrame({'Key_2':['k0','k1','k2','k3'],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3']
})

# %%
izq.merge(der,on='Key')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18092/387700618.py in <module>
# ----> 1 izq.merge(der,on='Key')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9184         from pandas.core.reshape.merge import merge
#    9185
# -> 9186         return merge(
#    9187             self,
#    9188             right,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     698             self.right_join_keys,
#     699             self.join_names,
# --> 700         ) = self._get_merge_keys()
#     701
#     702         # validate the merge keys dtypes. We may need to coerce
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1090                     if not is_rkey(rk):
#    1091                         if rk is not None:
# -> 1092                             right_keys.append(right._get_label_or_level_values(rk))
#    1093                         else:
#    1094                             # work-around for merge_asof(right_index=True)
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'Key'

# %% [markdown]
# Arroja error porque esa llave no existe en ambos data frames
#
# Esto se puede solucionar fácilmente

# %%
izq.merge(der,left_on='Key',right_on='Key_2')
# Out:
#   Key   A   B Key_2   C   D
# 0  k0  A0  B0    k0  C0  D0
# 1  k1  A1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2
# 3  k3  A3  B3    k3  C3  D3

# %%
izq = pd.DataFrame({'Key':['k0','k1','k2','k3'],
'A':['A0','A1','A2','A3'],
'B':['B0','B1','B2','B3']
})

der = pd.DataFrame({'Key_2':['k0','k1','k2',np.nan],
'C':['C0','C1','C2','C3'],
'D':['D0','D1','D2','D3']
})

# %%
izq.merge(der,left_on='Key',right_on='Key_2')
# Out:
#   Key   A   B Key_2   C   D
# 0  k0  A0  B0    k0  C0  D0
# 1  k1  A1  B1    k1  C1  D1
# 2  k2  A2  B2    k2  C2  D2

# %% [markdown]
# Aquí no presenta el key k3, porque no existe en el segundo datframe, es un inner join

# %%
izq.merge(der,left_on='Key',right_on='Key_2',how='left')
# Out:
#   Key   A   B Key_2    C    D
# 0  k0  A0  B0    k0   C0   D0
# 1  k1  A1  B1    k1   C1   D1
# 2  k2  A2  B2    k2   C2   D2
# 3  k3  A3  B3   NaN  NaN  NaN

# %% [markdown]
# El comando left, es para indicar la proridad de la izquierda

# %% [markdown]
# ## Join - index match
#
# Es una herramienta de pandas que sirve para hacer combinaciones pero la diferencia es que lo hace por índices

# %%
izq = pd.DataFrame({'A':['A0','A1','A2'],
'B':['B0','B1','B2']},index = ['k0','k1','k2'])

der = pd.DataFrame({'C':['C0','C1','C2'],
'D':['D0','D1','D2']},index = ['k0','k2','k3'])

# %%
izq.join(der)
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
izq.join(der, how='inner') #Lo que hace match a nivel de index deja fuera lo que no está, ambos comparten k0 y k2
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C1  D1

# %%
izq.join(der, how='left')
# Out:
#      A   B    C    D
# k0  A0  B0   C0   D0
# k1  A1  B1  NaN  NaN
# k2  A2  B2   C1   D1

# %%
izq.join(der, how='right')
# Out:
#       A    B   C   D
# k0   A0   B0  C0  D0
# k2   A2   B2  C1  D1
# k3  NaN  NaN  C2  D2

# %%
izq.join(der, how='outer') #Respta los join pero trae todo
# Out:
#       A    B    C    D
# k0   A0   B0   C0   D0
# k1   A1   B1  NaN  NaN
# k2   A2   B2   C1   D1
# k3  NaN  NaN   C2   D2
